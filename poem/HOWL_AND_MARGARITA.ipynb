# %% [markdown]
# <a href="https://colab.research.google.com/github/cewbewus/creativecode/blob/master/HOWL_AND_MARGARITA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Let's Make Poetry
# This is a Python notebook that you, a student in my Creative Coding class, may find a useful starting point for your poetry project. This notebook allows you to create cells with text, like the one I'm typing in now, and cells with code like the ones below.
#
# The next cell contains a code snippet that will allow you to upload any text file, the contents of which will be stored in a string variable called `text`.
#
# To try it out, save a copy of this notebook to your Google Drive and run the next cell.

# %%
from google.colab import files
import random
from textblob import TextBlob
uploaded = files.upload()
for fn in uploaded.keys():
  text = uploaded[fn].decode()
  
from google.colab import files
import random
from textblob import TextBlob
uploaded = files.upload()
for fn in uploaded.keys():
  text2 = uploaded[fn].decode()
# Out:
#      <input type="file" id="files-f1c44c73-7902-4285-af4b-5e665afbefe9" name="files[]" multiple disabled />
#      <output id="result-f1c44c73-7902-4285-af4b-5e665afbefe9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving themm.txt to themm.txt
#      <input type="file" id="files-b90c4d24-9926-4803-93a8-a596567beeff" name="files[]" multiple disabled />
#      <output id="result-b90c4d24-9926-4803-93a8-a596567beeff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Howl.txt to Howl.txt

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
master = TextBlob(text)
howl = TextBlob(text2)

#text_random = master.sentences[random.randint(0, len(master.sentences)-1)]
#word_random = master.words[random.randint(0, len(master.words)-1)]

#for x in range(0,7):
#  print(master.words[random.randint(0, len(master.words)-1)]) 

#print(master.sentences[random.randint(0, len(master.sentences)-1)])
#print(master.words[random.randint(0, len(master.words)-1)]) 

NNP = []
VBG = []
NN = []
PRP = [] 
MD = []
IN = []
RB = []
RBR = []
JJ = []
JJR = []
CC = []
WRB = []
VBP = []
VB = []
PRPS = []
TO = []
RP = []
VBD = []
DT = []
CD = []
EX = []
FW = []
LS = []
NNPS = []
PDT = []
POS = []
RBS = []
SYM = []
UH = []
VBN = []
VBZ = []
WDT = []
WP = []
WPS = []
JJS = []
NNS = []

for  word,pos in master.tags:
  #print (word,pos)
  if (pos == 'NNS'):
    NNS.append(word)
  if (pos == 'JJS'):
    JJS.append(word)
  if (pos == 'WP$'):
    WPS.append(word)
  if (pos == 'WP'):
    WP.append(word)
  if (pos == 'WDT'):
    WDT.append(word)
  if (pos == 'VBZ'):
    VBZ.append(word)
  if (pos == 'VBN'):
    VBN.append(word)
  if (pos == 'UH'):
    UH.append(word)
  if (pos == 'SYM'):
    SYM.append(word)
  if (pos == 'RBS'):
    RBS.append(word)
  if (pos == 'POS'):
    POS.append(word)
  if (pos == 'PDT'):
    PDT.append(word)
  if (pos == 'NNPS'):
    NNPS.append(word)
  if (pos == 'LS'):
    LS.append(word)
  if (pos == 'FW'):
    FW.append(word)
  if (pos == 'EX'):
    EX.append(word)
  if (pos == 'CD'):
    CD.append(word)
  if (pos == 'DT'):
    DT.append(word)
  if (pos == 'NNP'):
    NNP.append(word)
  if (pos =='VB'):
    VB.append(word)
  if (pos == 'VBD'):
    VBD.append(word)
  if (pos == 'VBG'):
    VBG.append(word)
  if (pos == 'VBP'):
    VBP.append(word)
  if (pos == 'NN'):
    NN.append(word)
  if (pos == 'PRP'):
    PRP.append(word)
  if (pos == 'PRP$'):
    PRPS.append(word)
  if (pos == 'MD'):
    MD.append(word)
  if (pos == 'IN'):
    IN.append(word) 
  if (pos == 'RB'):
    RB.append(word)
  if (pos == 'RBR'):
    RBR.append(word)
  if (pos == 'JJ'):
    JJ.append(word)
  if (pos == 'JJR'):
    JJR.append(word)
  if (pos == 'CC'):
    CC.append(word)
  if (pos == 'WRB'):
    WRB.append(word)
  if (pos == 'TO'):
    TO.append(word)
  if (pos == 'RP'):
    RP.append(word)

# %%
for x in range(len(FW)): 
    print (FW[x])
# Out:
# de
# perche
# de
# perche
# swept
# miss
# en
# madonna
# empty
# moonlit
# maid

# %%
print(random.choice(NN))
print(random.choice(IN),random.choice(NNP),random.choice(NNP))
print("\n")
print(random.choice(IN),random.choice(NNP),random.choice(NNP))
print("\n")
print("I")
print("\n")
print(random.choice(PRP),random.choice(VBD),random.choice(DT),random.choice(JJS),random.choice(NNS),random.choice(IN),random.choice(PRPS),random.choice(NN),random.choice(VBN),random.choice(IN),random.choice(NN),",",random.choice(VBG),random.choice(JJ),random.choice(JJ),",")
print(random.choice(VBG),random.choice(PRP),random.choice(IN),random.choice(DT),random.choice(JJ),random.choice(NNS),random.choice(IN),random.choice(NN),random.choice(VBG),random.choice(IN),random.choice(DT),random.choice(JJ),random.choice(JJ),",")
print(random.choice(VBD),random.choice(NNS),random.choice(VBG),random.choice(IN),random.choice(DT),random.choice(JJ),random.choice(RB),random.choice(NN),random.choice(TO),random.choice(DT),random.choice(JJ),random.choice(NN),random.choice(IN),random.choice(DT),random.choice(NN),random.choice(IN),random.choice(NN),",")
print(random.choice(WP),random.choice(NN),random.choice(CC),random.choice(NNS), random.choice(CC), random.choice(JJ), random.choice(CC), random.choice(JJ), random.choice(VBD), random.choice(RP), random.choice(VBG), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(JJ), random.choice(NNS), random.choice(VBG), random.choice(IN), random.choice(DT), random.choice(NNS), random.choice(IN), random.choice(NNS), random.choice(VBG), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(PRPS), random.choice(NNS), random.choice(TO), random.choice(NNP), random.choice(IN), random.choice(DT), random.choice(NNP), random.choice(CC), random.choice(VBD), random.choice(JJ), random.choice(NNS), random.choice(VBG), random.choice(IN), random.choice(NN), random.choice(NNS), random.choice(VBD),",")
print(random.choice(WP), random.choice(VBD), random.choice(IN), random.choice(NNS), random.choice(IN), random.choice(JJ), random.choice(JJ), random.choice(NNS), random.choice(VBG), random.choice(NNP), random.choice(CC), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NNS), random.choice(IN), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(VBN), random.choice(IN), random.choice(DT), random.choice(NNS), random.choice(IN), random.choice(JJ), random.choice(CC), random.choice(VBG), random.choice(JJ), random.choice(NNS), random.choice(IN), random.choice(DT), random.choice(NNS), random.choice(IN), random.choice(DT), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(IN), random.choice(JJ), random.choice(NNS), random.choice(IN), random.choice(NN),",", random.choice(VBG), random.choice(PRPS), random.choice(NN), random.choice(IN), random.choice(NNS), random.choice(CC), random.choice(VBG), random.choice(TO), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(VBN), random.choice(IN), random.choice(PRPS), random.choice(JJ), random.choice(NNS), random.choice(VBG), random.choice(IN), random.choice(NNS), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(NN), random.choice(IN), random.choice(NNP),",")
print(random.choice(WP), random.choice(VBP), random.choice(NN), random.choice(IN), random.choice(NN), random.choice(NNS), random.choice(CC), random.choice(VBD), random.choice(NN), random.choice(IN), random.choice(NNP),",",random.choice(VBD), random.choice(CC), random.choice(VBD), random.choice(PRPS), random.choice(NNS), random.choice(NN), random.choice(IN), random.choice(NN))
print(random.choice(IN), random.choice(NNS),",", random.choice(IN), random.choice(NNS),",", random.choice(IN), random.choice(JJ), random.choice(NNS),",", random.choice(NN), random.choice(CC), random.choice(NN), random.choice(CC), random.choice(JJ), random.choice(NNS),",")
print(random.choice(JJ), random.choice(JJ), random.choice(NNS), random.choice(IN), random.choice(VBG), random.choice(NN), random.choice(CC), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(VBG), random.choice(IN), random.choice(NNS), random.choice(IN), random.choice(NNP), random.choice(CC), random.choice(NNP),",", random.choice(VBG), random.choice(PDT), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(NN), random.choice(IN),",")
print(random.choice(NNP), random.choice(NNS), random.choice(IN), random.choice(NNS),",", random.choice(JJ), random.choice(JJ), random.choice(NN), random.choice(JJ), random.choice(NN),",", random.choice(NN), random.choice(NN), random.choice(IN), random.choice(CC), random.choice(NNS),",", random.choice(JJ), random.choice(NNS), random.choice(IN), random.choice(JJ), random.choice(NN), random.choice(JJ), random.choice(JJ), random.choice(JJ), random.choice(NN),",", random.choice(NN), random.choice(CC), random.choice(NN), random.choice(CC), random.choice(NN), random.choice(NNS), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(NNS), random.choice(IN), random.choice(NNP),",", random.choice(NN), random.choice(NNS), random.choice(CC), random.choice(JJ), random.choice(NN), random.choice(NN), random.choice(IN), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(PRP), random.choice(IN), random.choice(NNP), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(NNP), random.choice(IN), random.choice(JJ), random.choice(NNP), random.choice(IN), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(NNS), random.choice(CC), random.choice(NNS), random.choice(VBD), random.choice(PRP), random.choice(RP), random.choice(VBG), random.choice(JJ), random.choice(CC), random.choice(VBD), random.choice(JJ), random.choice(IN), random.choice(NN), random.choice(DT), random.choice(VBD), random.choice(IN), random.choice(NN), random.choice(IN), random.choice(CC), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(NNP),",")
print(random.choice(WP), random.choice(VBD), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(NNP),"’s", random.choice(VBD), random.choice(RP), random.choice(CC), random.choice(VBD), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(NN), random.choice(IN), random.choice(JJ), random.choice(NNP),"’s",",", random.choice(VBG), random.choice(IN), random.choice(CC), random.choice(NN), random.choice(IN), random.choice(NN), random.choice(IN), random.choice(CC), random.choice(JJ), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(RB), random.choice(JJ), random.choice(NNS), random.choice(IN), random.choice(NN), random.choice(TO), random.choice(VB), random.choice(TO), random.choice(VB), random.choice(TO), random.choice(NNP), random.choice(IN), random.choice(NN), random.choice(TO), random.choice(DT), random.choice(NNP),",")
print(random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(JJ), random.choice(NNS), random.choice(VBG), random.choice(RP), random.choice(DT), random.choice(NNS), random.choice(IN), random.choice(NN), random.choice(NNS), random.choice(IN), random.choice(NNS), random.choice(IN), random.choice(NNP), random.choice(IN), random.choice(IN), random.choice(DT), random.choice(NN),",")
print(random.choice(VBG), random.choice(VBG), random.choice(VBG), random.choice(VBG), random.choice(NNS), random.choice(CC), random.choice(NNS), random.choice(CC), random.choice(NNS), random.choice(CC), random.choice(NN), random.choice(NNS), random.choice(CC), random.choice(NNS), random.choice(IN), random.choice(NNS), random.choice(CC), random.choice(NNS), random.choice(CC), random.choice(NNS),",")
print(random.choice(JJ), random.choice(NNS), random.choice(VBN), random.choice(IN), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(CD), random.choice(NNS), random.choice(CC), random.choice(NNS), random.choice(IN), random.choice(JJ), random.choice(NNS),",", random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(IN), random.choice(RB), random.choice(NN), random.choice(NNP), random.choice(VBG), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(JJ), random.choice(NN), random.choice(NN), random.choice(IN), random.choice(NNP),",")
print(random.choice(VBG), random.choice(JJ), random.choice(NNS), random.choice(CC), random.choice(JJ), random.choice(NNS), random.choice(CC), random.choice(NNS), random.choice(IN), random.choice(NNP), random.choice(IN), random.choice(NN), random.choice(IN), random.choice(NNP),"’s", random.choice(JJ), random.choice(JJ), random.choice(NN),",")   
print(random.choice(WP), random.choice(VBD), random.choice(RB), random.choice(CC), random.choice(RB), random.choice(IN), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(NN), random.choice(VBG), random.choice(WRB), random.choice(TO), random.choice(VB),",", random.choice(CC), random.choice(VBD),",", random.choice(VBG), random.choice(DT), random.choice(NN), random.choice(NNS),",")
print(random.choice(WP), random.choice(VBD), random.choice(NNS), random.choice(IN), random.choice(NNS), random.choice(NNS), random.choice(NNS), random.choice(VBG), random.choice(IN), random.choice(NN), random.choice(IN), random.choice(JJ), random.choice(NNS), random.choice(IN), random.choice(NN), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(NNP), random.choice(NNP), random.choice(NNP), random.choice(IN), random.choice(DT), random.choice(NNP), random.choice(NN), random.choice(CC), random.choice(NN), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(RB), random.choice(VBN), random.choice(IN), random.choice(PRPS), random.choice(NNS), random.choice(IN), random.choice(NNP),",")   
print(random.choice(WP), random.choice(VBD), random.choice(PRP), random.choice(IN), random.choice(DT), random.choice(NNS), random.choice(IN), random.choice(NNP), random.choice(VBG), random.choice(JJ), random.choice(JJ), random.choice(NNS), random.choice(WP), random.choice(VBD), random.choice(JJ), random.choice(JJ), random.choice(NNS),",")
print(random.choice(WP), random.choice(VBD), random.choice(PRP), random.choice(VBD), random.choice(RB), random.choice(JJ), random.choice(WRB), random.choice(NNP), random.choice(VBD), random.choice(IN), random.choice(JJ), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(IN), random.choice(NNS), random.choice(IN), random.choice(DT), random.choice(NNP), random.choice(IN), random.choice(NNP), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(NN), random.choice(NN), random.choice(NN), random.choice(NN), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(JJ), random.choice(CC), random.choice(JJ), random.choice(IN), random.choice(NNP), random.choice(VBG), random.choice(NN), random.choice(CC), random.choice(NN), random.choice(CC), random.choice(NN),",", random.choice(CC), random.choice(VBD), random.choice(DT), random.choice(JJ), random.choice(NNP), random.choice(TO), random.choice(VB), random.choice(IN), random.choice(NNP), random.choice(CC), random.choice(NN),",", random.choice(DT), random.choice(JJ), random.choice(NN),",", random.choice(CC), random.choice(RB), random.choice(VBD), random.choice(NN), random.choice(TO), random.choice(NNP),",")
print(random.choice(WP), random.choice(VBD), random.choice(IN), random.choice(DT), random.choice(NNS), random.choice(IN), random.choice(NNP), random.choice(VBG), random.choice(IN), random.choice(NN), random.choice(CC), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(NNS), random.choice(CC), random.choice(DT), random.choice(NN), random.choice(CC), random.choice(NN), random.choice(IN), random.choice(NN), random.choice(VBN), random.choice(IN), random.choice(NN), random.choice(NNP),",")
print(random.choice(WP), random.choice(VBD), random.choice(IN), random.choice(DT), random.choice(NNP), random.choice(VBG), random.choice(DT), random.choice(NNP), random.choice(IN), random.choice(NNS), random.choice(CC), random.choice(NNS), random.choice(IN), random.choice(JJ), random.choice(JJ), random.choice(NNS), random.choice(JJ), random.choice(IN), random.choice(PRPS), random.choice(JJ), random.choice(NN), random.choice(VBG), random.choice(RP), random.choice(JJ), random.choice(NNS),",")
print(random.choice(WP), random.choice(VBD), random.choice(NN), random.choice(NNS), random.choice(IN), random.choice(PRPS), random.choice(NNS), random.choice(VBG), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(NN), random.choice(IN), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(NN), random.choice(NNS), random.choice(IN), random.choice(NNP), random.choice(VBG), random.choice(CC), random.choice(VBG), random.choice(IN), random.choice(DT), random.choice(NNS), random.choice(IN), random.choice(NNP), random.choice(VBD), random.choice(PRP), random.choice(RP),",", random.choice(CC), random.choice(VBD), random.choice(RP), random.choice(NN),",", random.choice(CC), random.choice(DT), random.choice(NNP), random.choice(NN), random.choice(RB), random.choice(VBD),",")
print(random.choice(WP), random.choice(VBD), random.choice(RP), random.choice(VBG), random.choice(IN), random.choice(JJ), random.choice(NNS), random.choice(JJ), random.choice(CC), random.choice(JJ), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(JJ), random.choice(NNS),",")
print(random.choice(WP), random.choice(VBD), random.choice(NNS), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(CC), random.choice(VBD), random.choice(IN), random.choice(NN), random.choice(IN), random.choice(NNS), random.choice(IN), random.choice(VBG), random.choice(DT), random.choice(NN), random.choice(CC), random.choice(PRPS), random.choice(JJ), random.choice(JJ), random.choice(NN), random.choice(NN), random.choice(CC), random.choice(JJ),",")
print(random.choice(WP), random.choice(VBD), random.choice(IN), random.choice(PRPS), random.choice(NNS), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(CC), random.choice(VBD), random.choice(VBN), random.choice(RP), random.choice(DT), random.choice(NN), random.choice(NN), random.choice(NNS), random.choice(CC), random.choice(NNS),",")
print(random.choice(WP), random.choice(VBD), random.choice(PRP), random.choice(VB), random.choice(VBN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(JJ), random.choice(NNS),",", random.choice(CC), random.choice(VBD), random.choice(IN), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(CC), random.choice(VBD), random.choice(VBN), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN),",", random.choice(DT), random.choice(NNS),",", random.choice(NNS), random.choice(IN), random.choice(NNP), random.choice(CC), random.choice(NNP), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NNS), random.choice(IN), random.choice(NNS), random.choice(CC), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(JJ), random.choice(NNS), random.choice(CC), random.choice(NNS), random.choice(VBG), random.choice(PRPS), random.choice(NN), random.choice(RB), random.choice(TO), random.choice(VB), random.choice(VB), random.choice(WP), random.choice(MD),",")
print(random.choice(WP), random.choice(VBD), random.choice(RB), random.choice(VBG), random.choice(TO), random.choice(VB), random.choice(CC), random.choice(VB), random.choice(RB), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(WRB), random.choice(DT), random.choice(JJ), random.choice(CC), random.choice(JJ), random.choice(NN), random.choice(VBD), random.choice(TO), random.choice(VB), random.choice(PRPS), random.choice(IN), random.choice(DT), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(JJ), random.choice(NNS), random.choice(TO), random.choice(DT), random.choice(CD), random.choice(JJ), random.choice(NNS), random.choice(IN), random.choice(NN), random.choice(DT), random.choice(CD), random.choice(NN), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(DT), random.choice(CD), random.choice(NN), random.choice(NN), random.choice(IN), random.choice(VBZ), random.choice(IN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(CC), random.choice(DT), random.choice(CD), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(VBZ), random.choice(NN), random.choice(CC), random.choice(NN), random.choice(IN), random.choice(PRPS), random.choice(NN), random.choice(CC), random.choice(VB), random.choice(DT), random.choice(JJ), random.choice(JJ), random.choice(NNS), random.choice(IN), random.choice(DT), random.choice(NN),"’s", random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(JJ), random.choice(CD), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(NN), random.choice(DT), random.choice(NN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(NNS), random.choice(DT), random.choice(NN), random.choice(CC), random.choice(VBD), random.choice(RP), random.choice(DT), random.choice(NN),",", random.choice(CC), random.choice(VBD), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(CC), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(CC), random.choice(VBD), random.choice(VBG), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(JJ), random.choice(NN), random.choice(CC), random.choice(VB), random.choice(NN), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(DT), random.choice(NNS), random.choice(IN), random.choice(DT), random.choice(CD), random.choice(NNS), random.choice(VBG), random.choice(IN), random.choice(DT), random.choice(NN),",", random.choice(CC), random.choice(VBD), random.choice(JJ), random.choice(VBD), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(CC), random.choice(VBD), random.choice(TO), random.choice(VB), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN),",", random.choice(VBG), random.choice(NNS), random.choice(IN), random.choice(NNS), random.choice(CC), random.choice(VBN), random.choice(IN), random.choice(DT), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(IN), random.choice(VBG), random.choice(IN), random.choice(NNP), random.choice(IN), random.choice(NN), random.choice(JJ), random.choice(NN),",", random.choice(NNP),",", random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NNS),",", random.choice(NN), random.choice(CC), random.choice(NN), random.choice(IN), random.choice(NNP),"—",random.choice(NN), random.choice(TO), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(PRPS), random.choice(JJ), random.choice(NNS), random.choice(IN), random.choice(NNS), random.choice(IN), random.choice(JJ), random.choice(NNS), random.choice(CC), random.choice(NN), random.choice(NNS),",", random.choice(NNS),"’", random.choice(JJ), random.choice(NNS),",", random.choice(IN), random.choice(NNS), random.choice(IN), random.choice(NNS), random.choice(CC), random.choice(IN), random.choice(JJ), random.choice(NNS), random.choice(IN), random.choice(JJ), random.choice(JJ), random.choice(JJ), random.choice(NN), random.choice(NNS), random.choice(CC), random.choice(JJ), random.choice(JJ), random.choice(NN), random.choice(NNS), random.choice(IN), random.choice(NNS),",", random.choice(CC), random.choice(NN), random.choice(NNS), random.choice(RB),",")
print(random.choice(WP), random.choice(VBD), random.choice(IN), random.choice(IN), random.choice(JJ), random.choice(JJ), random.choice(NNS),",", random.choice(VBD), random.choice(VBN), random.choice(IN), random.choice(NNS),",", random.choice(VBD), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NNP),",", random.choice(CC), random.choice(VBD), random.choice(PRP), random.choice(RP), random.choice(IN), random.choice(IN), random.choice(NNS), random.choice(JJ), random.choice(IN), random.choice(JJ), random.choice(NNP), random.choice(CC), random.choice(NNS), random.choice(IN), random.choice(NNP), random.choice(JJ), random.choice(NN), random.choice(CC), random.choice(VBD), random.choice(IN), random.choice(JJ), random.choice(NNS),",")
print(random.choice(WP), random.choice(VBD), random.choice(CD), random.choice(NN), random.choice(IN), random.choice(PRPS), random.choice(NNS), random.choice(JJ), random.choice(IN), random.choice(NN), random.choice(IN), random.choice(CD), random.choice(NN), random.choice(NNS), random.choice(VBG), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NNP), random.choice(TO), random.choice(VB), random.choice(TO), random.choice(DT), random.choice(NN), random.choice(JJ), random.choice(IN), random.choice(NN), random.choice(CC), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(JJ), random.choice(JJ), random.choice(NNS), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(NNS), random.choice(IN), random.choice(DT), random.choice(NNP), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(CC), random.choice(PRPS), random.choice(NNS), random.choice(MD), random.choice(VB), random.choice(VBN), random.choice(IN), random.choice(NN), random.choice(IN), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(DT), random.choice(NN), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(DT), random.choice(VBD), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NNS), random.choice(IN), random.choice(NNP),",")
print(random.choice(WP), random.choice(VBD), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NNS), random.choice(IN), random.choice(PRPS), random.choice(NNS), random.choice(JJ), random.choice(IN), random.choice(NNS), random.choice(CC), random.choice(JJ), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(IN), random.choice(NNS), random.choice(VBG), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN),",", random.choice(DT), random.choice(JJ), random.choice(RP), random.choice(TO), random.choice(VB), random.choice(NNS), random.choice(IN), random.choice(PRPS), random.choice(NNS),",")
print(random.choice(WP), random.choice(VBD), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(NNP), random.choice(VBD), random.choice(IN), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(VBD), random.choice(IN), random.choice(JJ), random.choice(NNS), random.choice(IN), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(DT), random.choice(NN), random.choice(VBG), random.choice(CC), random.choice(VBG), random.choice(RP), random.choice(JJ), random.choice(NNS), random.choice(WDT), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(VBD), random.choice(NNS), random.choice(IN), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(JJ), random.choice(NNS), random.choice(NN), random.choice(NN), random.choice(NNS), random.choice(NN), random.choice(NN), random.choice(CC), random.choice(NNS), random.choice(VBG), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(JJ), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(PRP), random.choice(IN), random.choice(NN), random.choice(NNS), random.choice(VBG), random.choice(IN), random.choice(DT), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(PRPS), random.choice(NNS), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(VB), random.choice(PRPS), random.choice(NN), random.choice(IN), random.choice(NN), random.choice(IN), random.choice(IN), random.choice(NN),",", random.choice(CC), random.choice(NN), random.choice(NNS), random.choice(VBD), random.choice(IN), random.choice(PRPS), random.choice(NNS), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(PRPS), random.choice(NNS), random.choice(CD), random.choice(NNS), random.choice(RB), random.choice(RB),",", random.choice(VBD), random.choice(RP), random.choice(CC), random.choice(VBD), random.choice(VBN), random.choice(TO), random.choice(VB), random.choice(JJ), random.choice(NNS), random.choice(WRB), random.choice(PRP), random.choice(VBD), random.choice(PRP), random.choice(VBD), random.choice(VBG), random.choice(JJ), random.choice(CC), random.choice(JJ),",")
print(random.choice(WP), random.choice(VBD), random.choice(VBN), random.choice(JJ), random.choice(IN), random.choice(PRPS), random.choice(JJ), random.choice(JJ), random.choice(NNS), random.choice(IN), random.choice(NNP), random.choice(IN), random.choice(NNS), random.choice(IN), random.choice(JJ), random.choice(NN), random.choice(CC), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(CC), random.choice(JJ), random.choice(NNS), random.choice(IN), random.choice(NN), random.choice(CC), random.choice(DT), random.choice(NN), random.choice(NNS), random.choice(IN), random.choice(DT), random.choice(NNS), random.choice(IN), random.choice(VBG), random.choice(CC), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(JJ), random.choice(JJ), random.choice(NN),",", random.choice(CC), random.choice(VBD), random.choice(VBN), random.choice(RB), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(JJ), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(IN), random.choice(DT), random.choice(NNP), random.choice(DT), random.choice(RB), random.choice(VBN), random.choice(CC), random.choice(VBN), random.choice(RB), random.choice(JJ), random.choice(CC), random.choice(VBN), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(NNP), random.choice(NN), random.choice(NNS), random.choice(CC), random.choice(NNS),",", random.choice(RB), random.choice(RB), random.choice(CD), random.choice(JJ), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(IN), random.choice(IN), random.choice(DT), random.choice(NNS), random.choice(IN), random.choice(NN),",", random.choice(VBD), random.choice(IN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(NN),",", random.choice(VBD), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN),",", random.choice(VBD), random.choice(IN), random.choice(NNS),",", random.choice(VBD), random.choice(DT), random.choice(IN), random.choice(DT), random.choice(NN),",", random.choice(VBD), random.choice(IN), random.choice(JJ), random.choice(NNS), random.choice(JJ), random.choice(JJ), random.choice(NN), random.choice(NNS), random.choice(IN), random.choice(JJ), random.choice(JJ), random.choice(JJ), random.choice(JJ), random.choice(NN), random.choice(VBD), random.choice(DT), random.choice(NN), random.choice(CC), random.choice(VBD), random.choice(RP), random.choice(VBG), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN),",", random.choice(NNS), random.choice(IN), random.choice(PRPS), random.choice(NNS), random.choice(CC), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(JJ), random.choice(NNS),",")
print(random.choice(WP), random.choice(VBD), random.choice(IN), random.choice(DT), random.choice(NNS), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(TO), random.choice(DT), random.choice(NN),"’s", random.choice(NN),random.choice(DT), random.choice(NN), random.choice(VB), random.choice(CC), random.choice(NNP), random.choice(JJ), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(JJ), random.choice(CD), random.choice(NNS), random.choice(TO), random.choice(VB), random.choice(RB), random.choice(IN), random.choice(PRP), random.choice(VBD), random.choice(DT), random.choice(NN), random.choice(CC), random.choice(PRP), random.choice(VBD), random.choice(DT), random.choice(NN), random.choice(CC), random.choice(PRP), random.choice(VBD), random.choice(DT), random.choice(NN), random.choice(TO), random.choice(VB), random.choice(RP), random.choice(VBN),random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(TO), random.choice(NNP),",", random.choice(WP), random.choice(VBD), random.choice(IN), random.choice(NNP),",", random.choice(WP), random.choice(VBD), random.choice(RB), random.choice(TO), random.choice(NNP), random.choice(CC), random.choice(VBN), random.choice(IN), random.choice(NN),",", random.choice(WP), random.choice(VBD), random.choice(IN), random.choice(NNP), random.choice(CC), random.choice(VBD), random.choice(CC), random.choice(VBD), random.choice(IN), random.choice(NNP), random.choice(CC), random.choice(RB), random.choice(VBD), random.choice(IN), random.choice(TO), random.choice(VB), random.choice(RP), random.choice(DT), random.choice(NN),",", random.choice(CC), random.choice(RB), random.choice(NNP), random.choice(VBZ), random.choice(JJ), random.choice(IN), random.choice(PRPS), random.choice(NNS),",")
print(random.choice(WP), random.choice(VBD), random.choice(IN), random.choice(PRP), random.choice(NNS), random.choice(IN), random.choice(JJ), random.choice(NNS), random.choice(VBG), random.choice(IN), random.choice(DT), random.choice(NN),"’s", random.choice(NN), random.choice(DT), random.choice(NN), random.choice(CC), random.choice(NNS),",", random.choice(IN), random.choice(DT), random.choice(NN), random.choice(VBD), random.choice(PRPS), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(IN), random.choice(PRPS), random.choice(NNS), random.choice(IN), random.choice(NN), random.choice(VBG), random.choice(IN), random.choice(JJ), random.choice(NNS), random.choice(IN), random.choice(JJ), random.choice(NNS), random.choice(CC), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(NN), random.choice(IN), random.choice(PRPS), random.choice(NNS), random.choice(WP), random.choice(VBP), random.choice(JJ), random.choice(NN), random.choice(TO), random.choice(NNP),",")
print(random.choice(WP), random.choice(VBD), random.choice(TO), random.choice(NNP), random.choice(TO), random.choice(VB),random.choice(DT),random.choice(NN),",", random.choice(CC), random.choice(NNP), random.choice(TO), random.choice(JJ), random.choice(NNP), random.choice(CC), random.choice(NNP), random.choice(TO), random.choice(NNS), random.choice(CC), random.choice(JJ), random.choice(NNP), random.choice(TO), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(CC), random.choice(NNP), random.choice(TO), random.choice(NNP), random.choice(TO), random.choice(NNP), random.choice(TO), random.choice(DT), random.choice(NNP), random.choice(CC), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(NN), random.choice(NNS), random.choice(VBG), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(NN), random.choice(CC), random.choice(VBD), random.choice(VBN), random.choice(IN), random.choice(PRPS), random.choice(NN), random.choice(CC), random.choice(PRPS), random.choice(NNS), random.choice(CC), random.choice(DT), random.choice(JJ), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(NN), random.choice(NN), random.choice(IN), random.choice(NNP), random.choice(NNS), random.choice(IN), random.choice(NNP), random.choice(CC), random.choice(RB), random.choice(VBN), random.choice(PRP), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NNS), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(JJ), random.choice(NNS), random.choice(CC), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(NN),",", random.choice(VBG), random.choice(JJ), random.choice(NN),",")
print(random.choice(CC), random.choice(WP), random.choice(VBD), random.choice(VBN), random.choice(RB), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(NN), random.choice(NNP), random.choice(NN), random.choice(NN), random.choice(NN), random.choice(JJ), random.choice(NN), random.choice(NN), random.choice(CC), random.choice(NN),",")
print(random.choice(WP), random.choice(IN), random.choice(JJ), random.choice(NN), random.choice(VBD), random.choice(RB), random.choice(CD), random.choice(JJ), random.choice(JJ), random.choice(NN),",", random.choice(VBG), random.choice(RB), random.choice(IN), random.choice(NN),",")
print(random.choice(VBG), random.choice(NNS), random.choice(RB), random.choice(RB), random.choice(JJ), random.choice(IN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(NN),",", random.choice(CC), random.choice(NNS), random.choice(CC), random.choice(NNS),",", random.choice(TO), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NNS), random.choice(IN), random.choice(DT), random.choice(NNP),",")
print(random.choice(NNP),"’s", random.choice(NNP),"’s", random.choice(CC), random.choice(NNP),"’s", random.choice(JJ), random.choice(NNS),",", random.choice(VBG), random.choice(IN), random.choice(DT), random.choice(NNS), random.choice(IN), random.choice(DT), random.choice(NN),",", random.choice(VBG), random.choice(CC), random.choice(VBG), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(NN), random.choice(NNS), random.choice(IN), random.choice(NN),",", random.choice(NNS), random.choice(IN), random.choice(NN), random.choice(DT), random.choice(NN),",", random.choice(NNS), random.choice(VBD), random.choice(IN), random.choice(NN), random.choice(IN), random.choice(JJ), random.choice(IN), random.choice(DT), random.choice(NN),",")
print(random.choice(IN), random.choice(NN), random.choice(RB), "******,", random.choice(CC), random.choice(DT),random.choice(DT), random.choice(JJ), random.choice(JJ), random.choice(NN), random.choice(VBD), random.choice(IN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(NN),",", random.choice(CC), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(VBD), random.choice(IN), random.choice(CD), "A.M.", random.choice(CC), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(VBD), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(NN), random.choice(CC), random.choice(DT), random.choice(JJ), random.choice(JJ), random.choice(NN), random.choice(VBD), random.choice(RB), random.choice(TO), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(JJ), random.choice(NN),",", random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(NN), random.choice(VBD), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN),",", random.choice(CC), random.choice(RB), random.choice(DT), random.choice(JJ),",", random.choice(NN), random.choice(CC), random.choice(DT), random.choice(JJ), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(NN),"—")
print(random.choice(UH),",", random.choice(NNP),",", random.choice(IN), random.choice(PRP), random.choice(VBP), random.choice(RB), random.choice(JJ), random.choice(PRP), random.choice(VBP), random.choice(RB), random.choice(JJ),",", random.choice(CC), random.choice(RB), random.choice(PRP),"’re", random.choice(RB), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(NN), random.choice(IN), random.choice(NN),"—")
print(random.choice(CC), random.choice(WP), random.choice(VBP), random.choice(VBD), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NNS), random.choice(VBN), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(NN), random.choice(DT), random.choice(NN), random.choice(NN), random.choice(CC), random.choice(DT), random.choice(VBG), random.choice(NN),",")
print(random.choice(WP), random.choice(VBD), random.choice(CC), random.choice(VBD), random.choice(JJ), random.choice(NNS), random.choice(IN), random.choice(NN), random.choice(CC), random.choice(NN), random.choice(IN), random.choice(NNS), random.choice(VBN),",", random.choice(CC), random.choice(VBD), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(CD), random.choice(JJ), random.choice(NNS), random.choice(CC), random.choice(VBD), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(CC), random.choice(VBD), random.choice(DT), random.choice(NN), random.choice(CC), random.choice(NN), random.choice(IN), random.choice(NN), random.choice(RB), random.choice(VBG), random.choice(IN), random.choice(NN), random.choice(IN), random.choice(NNP), random.choice(NNP), random.choice(NNP), random.choice(NNP),",")
print(random.choice(TO), random.choice(VB), random.choice(IN), random.choice(NN), random.choice(CC), random.choice(NN), random.choice(IN), random.choice(JJ), random.choice(JJ), random.choice(NN), random.choice(CC), random.choice(NN), random.choice(IN), random.choice(PRP), random.choice(VBP), random.choice(CC), random.choice(JJ), random.choice(CC), random.choice(VBG), random.choice(IN), random.choice(NN),",", random.choice(VBN), random.choice(RB), random.choice(VBG), random.choice(RP), random.choice(DT), random.choice(NN), random.choice(TO), random.choice(VB), random.choice(TO), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(NN), random.choice(IN), random.choice(PRP), random.choice(JJ), random.choice(CC), random.choice(JJ), random.choice(NN),",")
print(random.choice(DT), random.choice(NN), random.choice(NN), random.choice(CC), random.choice(NN), random.choice(VBD), random.choice(IN), random.choice(NN),",", random.choice(JJ),",", random.choice(RB), random.choice(VBG), random.choice(RP), random.choice(RB), random.choice(WP), random.choice(MD), random.choice(VB), random.choice(VBN), random.choice(TO), random.choice(VB), random.choice(IN), random.choice(NN), random.choice(VBN), random.choice(IN), random.choice(NN),",")
print(random.choice(CC), random.choice(NN), random.choice(VB), random.choice(IN), random.choice(DT), random.choice(PRP), random.choice(JJ), random.choice(NNS), random.choice(IN), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(CC), random.choice(VBD), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(NNP),"’s", random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(NN), random.choice(IN), random.choice(JJ), random.choice(FW), random.choice(FW), random.choice(FW), random.choice(FW), random.choice(FW), random.choice(NN), random.choice(NN), random.choice(WDT), random.choice(VBD), random.choice(DT), random.choice(NN), random.choice(RP), random.choice(TO), random.choice(DT), random.choice(JJ), random.choice(NN))
print(random.choice(IN), random.choice(DT), random.choice(JJ), random.choice(NN), random.choice(IN), random.choice(DT), random.choice(NN), random.choice(IN), random.choice(NN), random.choice(VBN), random.choice(IN), random.choice(IN), random.choice(PRPS), random.choice(JJ), random.choice(NNS), random.choice(JJ), random.choice(TO), random.choice(VB), random.choice(DT), random.choice(CD), random.choice(NNS),".")
print("\n")
print("\n")
print("II")
print("\n")
print("What sphinx of cement and aluminum bashed open their skulls and ate up their brains and imagination?")
print("Moloch! Solitude! Filth! Ugliness! Ashcans and unobtainable dollars! Children screaming under the stairways! Boys sobbing in armies! Old men weeping in the parks!")
print("Moloch! Moloch! Nightmare of Moloch! Moloch the loveless! Mental Moloch! Moloch the heavy judger of men!")
print("Moloch the incomprehensible prison! Moloch the crossbone soulless jailhouse and Congress of sorrows! Moloch whose buildings are judgment! Moloch the vast stone of war! Moloch the stunned governments!")
print("Moloch whose mind is pure machinery! Moloch whose blood is running money! Moloch whose fingers are ten armies! Moloch whose breast is a cannibal dynamo! Moloch whose ear is a smoking tomb!")
print("Moloch whose eyes are a thousand blind windows! Moloch whose skyscrapers stand in the long streets like endless Jehovahs! Moloch whose factories dream and croak in the fog! Moloch whose smoke-stacks and antennae crown the cities!")
print("Moloch whose love is endless oil and stone! Moloch whose soul is electricity and banks! Moloch whose poverty is the specter of genius! Moloch whose fate is a cloud of sexless hydrogen! Moloch whose name is the Mind!")
print("Moloch in whom I sit lonely! Moloch in whom I dream Angels! Crazy in Moloch! Cocksucker in Moloch! Lacklove and manless in Moloch!")
print("Moloch who entered my soul early! Moloch in whom I am a consciousness without a body! Moloch who frightened me out of my natural ecstasy! Moloch whom I abandon! Wake up in Moloch! Light streaming out of the sky!")
print("Moloch! Moloch! Robot apartments! invisible suburbs! skeleton treasuries! blind capitals! demonic industries! spectral nations! invincible madhouses! granite cocks! monstrous bombs!")
print("They broke their backs lifting Moloch to Heaven! Pavements, trees, radios, tons! lifting the city to Heaven which exists and is everywhere about us!")
print("Visions! omens! hallucinations! miracles! ecstasies! gone down the American river!")
print("Dreams! adorations! illuminations! religions! the whole boatload of sensitive bullshit!")
print("Breakthroughs! over the river! flips and crucifixions! gone down the flood! Highs! Epiphanies! Despairs! Ten years’ animal screams and suicides! Minds! New loves! Mad generation! down on the rocks of Time!")
print("Real holy laughter in the river! They saw it all! the wild eyes! the holy yells! They bade farewell! They jumped off the roof! to solitude! waving! carrying flowers! Down to the river! into the street!")
print("\n")
print("\n")
print("III")
print("\n")
print(random.choice(NNP), random.choice(NNP),"!", random.choice(PRP),"’m", random.choice(IN), random.choice(PRP), random.choice(IN), random.choice(PRP))
print("   where you’re madder than I am")
print(random.choice(PRP),"’m", random.choice(IN), random.choice(PRP), random.choice(IN), random.choice(PRP))
print("   where you must feel very strange")
print(random.choice(PRP),"’m", random.choice(IN), random.choice(PRP), random.choice(IN), random.choice(PRP))
print("   where you imitate the shade of my mother")
print(random.choice(PRP),"’m", random.choice(IN), random.choice(PRP), random.choice(IN), random.choice(PRP))
print("   where you’ve murdered your twelve secretaries")
print(random.choice(PRP),"’m", random.choice(IN), random.choice(PRP), random.choice(IN), random.choice(PRP))
print("   where you laugh at this invisible humor")
print(random.choice(PRP),"’m", random.choice(IN), random.choice(PRP), random.choice(IN), random.choice(PRP))
print("   where we are great writers on the same dreadful typewriter")
print(random.choice(PRP),"’m", random.choice(IN), random.choice(PRP), random.choice(IN), random.choice(PRP))
print("   where your condition has become serious and is reported on the radio")
print(random.choice(PRP),"’m", random.choice(IN), random.choice(PRP), random.choice(IN), random.choice(PRP))
print("   where the faculties of the skull no longer admit the worms of the senses")
print(random.choice(PRP),"’m", random.choice(IN), random.choice(PRP), random.choice(IN), random.choice(PRP))
print("   where you drink the tea of the breasts of the spinsters of Utica")
print(random.choice(PRP),"’m", random.choice(IN), random.choice(PRP), random.choice(IN), random.choice(PRP))
print("   where you pun on the bodies of your nurses the harpies of the Bronx")
print(random.choice(PRP),"’m", random.choice(IN), random.choice(PRP), random.choice(IN), random.choice(PRP))
print("   where you scream in a straightjacket that you’re losing the game of the actual pingpong of the abyss")
print(random.choice(PRP),"’m", random.choice(IN), random.choice(PRP), random.choice(IN), random.choice(PRP))
print("   where you bang on the catatonic piano the soul is innocent and immortal it should never die ungodly in an armed madhouse")
print(random.choice(PRP),"’m", random.choice(IN), random.choice(PRP), random.choice(IN), random.choice(PRP))
print("   where fifty more shocks will never return your soul to its body again from its pilgrimage to a cross in the void")
print(random.choice(PRP),"’m", random.choice(IN), random.choice(PRP), random.choice(IN), random.choice(PRP))
print("   where you accuse your doctors of insanity and plot the Hebrew socialist revolution against the fascist national Golgotha")
print(random.choice(PRP),"’m", random.choice(IN), random.choice(PRP), random.choice(IN), random.choice(PRP))
print("   where you will split the heavens of Long Island and resurrect your living human Jesus from the superhuman tomb")
print(random.choice(PRP),"’m", random.choice(IN), random.choice(PRP), random.choice(IN), random.choice(PRP))
print("   where there are twentyfive thousand mad comrades all together singing the final stanzas of the Internationale")
print(random.choice(PRP),"’m", random.choice(IN), random.choice(PRP), random.choice(IN), random.choice(PRP))
print("   where we hug and kiss the United States under our bedsheets the United States that coughs all night and won’t let us sleep")
print(random.choice(PRP),"’m", random.choice(IN), random.choice(PRP), random.choice(IN), random.choice(PRP))
print("   where we wake up electrified out of the coma by our own souls’ airplanes roaring over the roof they’ve come to drop angelic bombs the hospital illuminates itself    imaginary walls collapse    O skinny legions run outside    O starry-spangled shock of mercy the eternal war is here    O victory forget your underwear we’re free")
print(random.choice(PRP),"’m", random.choice(IN), random.choice(PRP), random.choice(IN), random.choice(PRP))
print("   in my dreams you walk dripping from a sea-journey on the highway across America in tears to the door of my cottage in the Western night")
# Out:
# night
# by Neptune Ivanovich
#
#
# for Gate Solovki
#
#
# I
#
#
# You saw an best remains of my serviette spread by spread , living absurd inexplicable ,
# crying he with the last temptations in sea wearing with the able aware ,
# gnashed candles putting With the prepared again auburn to the wonderful anatomist with a cushion with corpse ,
# whom everything and cards and to-morrow and yellow said off fingering over a weakened floor of hoarse victims turning that the idols except streetlamps weeping buckskin ,
# who departed my foreigners to Pushkino of a Commission or mentioned terrible lights appearing on something 'You leaped ,
# who pointed on hills by delighted complimentary visitors coming Roman but singed broom of a terraces with argue ,
# who began failed than This 'Upstairs so straight but peering long up on the nightingales before an suppose ,
# what had from anonymous 'I on mirror , preparing their head into men and standing to the pocket As the crime ,
# ...
